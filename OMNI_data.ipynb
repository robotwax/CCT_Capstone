# %%
import pandas as pd

df = pd.read_csv('geomag_hurricane_DORIAN.csv')
df.head()
# Out:
#                   date  storm_id    name cat   lat  long  \
# 0  2019-08-24 06:00:00  AL052019  DORIAN  TD  10.3 -46.4
# 1  2019-08-24 12:00:00  AL052019  DORIAN  TD  10.4 -47.5
# 2  2019-08-24 18:00:00  AL052019  DORIAN  TS  10.6 -48.7
# 3  2019-08-25 00:00:00  AL052019  DORIAN  TS  10.8 -49.9
# 4  2019-08-25 06:00:00  AL052019  DORIAN  TS  11.0 -51.0
#
#    max_sust_windspeed(knots)  min_pressure(millibars)  dec_time            H  \
# 0                         25                     1011       6.0  13175.58688
# 1                         30                     1010      12.0  13184.76876
# 2                         35                     1008      18.0  13166.13190
# 3                         35                     1008       0.0  13173.02186
# 4                         35                     1008       6.0  13205.02688
#
#            D            Z             M        dist         FM
# 0  328.38938  53904.52748  55537.195786    0.000000   0.000000
# ...

# %%
df.tail()
# Out:
#                    date  storm_id    name cat   lat  long  \
# 59  2019-09-08 00:00:00  AL052019  DORIAN  LO  45.2 -62.9
# 60  2019-09-08 06:00:00  AL052019  DORIAN  EX  47.6 -61.9
# 61  2019-09-08 12:00:00  AL052019  DORIAN  EX  49.4 -60.4
# 62  2019-09-08 18:00:00  AL052019  DORIAN  EX  50.8 -57.9
# 63  2019-09-09 00:00:00  AL052019  DORIAN  EX  51.6 -54.8
#
#     max_sust_windspeed(knots)  min_pressure(millibars)  dec_time            H  \
# 59                         80                      956       0.0  13049.43830
# 60                         75                      960       6.0  13251.76812
# 61                         70                      962      12.0  13128.40064
# 62                         60                      966      18.0  13179.71876
# 63                         50                      980       0.0  13186.19626
#
#             D             Z             M        dist         FM
# 59 -288.03205  53965.287525  55559.747637  299.448354  49.908059
# ...

# %%
pip install speasy
# Out:
# ...
#      |████████████████████████████████| 42 kB 1.4 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 6.7 MB 6.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 44 kB 4.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 342 kB 5.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 100 kB 4.1 MB/s ta 0:00:01
# ...
#      |████████████████████████████████| 54 kB 4.5 MB/s eta 0:00:01
# ...
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# ...
#      |████████████████████████████████| 41 kB 1.8 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speasy as spz
ace_mag = spz.get_data('amda/imf', "2016-6-2", "2016-6-5")

# %%
amda_tree = spz.inventory.data_tree.amda
ace_mag = spz.get_data(amda_tree.Parameters.ACE.MFI.ace_imf_all.imf, "2016-6-2", "2016-6-3")

# %%
ace_mag

# %%
ace_mag.plot()
# Out:
# <AxesSubplot:>

# %%
amda_tree = spz.inventory.data_tree.amda
ace_mag = spz.get_data(amda_tree.Parameters.OMNI, "2016-6-2", "2016-6-3")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xj/29kl316s2v94r6z0nbw_9l8w0000gn/T/ipykernel_11427/214300354.py in <module>
#       1 amda_tree = spz.inventory.data_tree.amda
# ----> 2 ace_mag = spz.get_data(amda_tree.Parameters.OMNI, "2016-6-2", "2016-6-3")
#
# /opt/anaconda3/envs/voila2/lib/python3.7/site-packages/speasy/__init__.py in get_data(product, start_time, stop_time, **kwargs)
#      75             return __PROVIDERS__[provider](product, start_time, stop_time, **kwargs)
#      76     else:
# ---> 77         components = product.split('/')
#      78         provider = components[0]
#      79         if provider in __PROVIDERS__:
#
# AttributeError: 'AMDAPathIndex' object has no attribute 'split'
